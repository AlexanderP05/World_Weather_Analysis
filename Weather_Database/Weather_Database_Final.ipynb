# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import config
import requests

# %%
# create a set of random lattitutde and longitude 
lats = np.random.uniform(low=-90.000, size=2000)
longs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_longs = zip(lats, longs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
coordinates = list(lats_longs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    country = citipy.nearest_city(coordinate[0], coordinate[1]).country_code
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append((city,country))
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 2000

# %%
from config import weather_api_key

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | saldanha
# Processing Record 2 of the Set 1 | ushuaia
# Processing Record 3 of the Set 1 | souillac
# Processing Record 4 of the Set 1 | bluff
# Processing Record 5 of the Set 1 | arraial do cabo
# Processing Record 6 of the Set 1 | hobart
# Processing Record 7 of the Set 1 | rikitea
# Processing Record 8 of the Set 1 | mataura
# Processing Record 9 of the Set 1 | hihifo
# City not found. Skipping...
# Processing Record 10 of the Set 1 | san antonio
# Processing Record 11 of the Set 1 | sibolga
# Processing Record 12 of the Set 1 | vaini
# City not found. Skipping...
# Processing Record 13 of the Set 1 | rikitea
# Processing Record 14 of the Set 1 | port alfred
# Processing Record 15 of the Set 1 | vaini
# City not found. Skipping...
# Processing Record 16 of the Set 1 | punta arenas
# Processing Record 17 of the Set 1 | port alfred
# Processing Record 18 of the Set 1 | cape town
# Processing Record 19 of the Set 1 | castro
# Processing Record 20 of the Set 1 | cidreira
# Processing Record 21 of the Set 1 | busselton
# Processing Record 22 of the Set 1 | punta arenas
# Processing Record 23 of the Set 1 | ushuaia
# Processing Record 24 of the Set 1 | albany
# Processing Record 25 of the Set 1 | ushuaia
# Processing Record 26 of the Set 1 | atuona
# Processing Record 27 of the Set 1 | mataura
# Processing Record 28 of the Set 1 | puerto ayora
# Processing Record 29 of the Set 1 | faanui
# Processing Record 30 of the Set 1 | lebu
# Processing Record 31 of the Set 1 | coffs harbour
# Processing Record 32 of the Set 1 | sumbawa
# Processing Record 33 of the Set 1 | hobart
# Processing Record 34 of the Set 1 | ushuaia
# Processing Record 35 of the Set 1 | atambua
# Processing Record 36 of the Set 1 | mount gambier
# Processing Record 37 of the Set 1 | punta arenas
# Processing Record 38 of the Set 1 | arraial do cabo
# Processing Record 39 of the Set 1 | mataura
# Processing Record 40 of the Set 1 | sucua
# Processing Record 41 of the Set 1 | albany
# Processing Record 42 of the Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of the Set 1 | mataura
# Processing Record 44 of the Set 1 | westport
# Processing Record 45 of the Set 1 | thinadhoo
# Processing Record 46 of the Set 1 | san carlos de bariloche
# Processing Record 47 of the Set 1 | mataura
# Processing Record 48 of the Set 1 | hobart
# Processing Record 49 of the Set 1 | jamestown
# Processing Record 50 of the Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 1 of the Set 2 | punta arenas
# Processing Record 2 of the Set 2 | luderitz
# Processing Record 3 of the Set 2 | vaini
# City not found. Skipping...
# Processing Record 4 of the Set 2 | avera
# Processing Record 5 of the Set 2 | port lincoln
# Processing Record 6 of the Set 2 | lebu
# Processing Record 7 of the Set 2 | vaini
# City not found. Skipping...
# Processing Record 8 of the Set 2 | chuy
# Processing Record 9 of the Set 2 | luderitz
# Processing Record 10 of the Set 2 | cape town
# Processing Record 11 of the Set 2 | souillac
# Processing Record 12 of the Set 2 | lebu
# Processing Record 13 of the Set 2 | lebu
# Processing Record 14 of the Set 2 | cape town
# Processing Record 15 of the Set 2 | georgetown
# Processing Record 16 of the Set 2 | hermanus
# Processing Record 17 of the Set 2 | bluff
# Processing Record 18 of the Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 19 of the Set 2 | cape town
# Processing Record 20 of the Set 2 | senanga
# Processing Record 21 of the Set 2 | albany
# Processing Record 22 of the Set 2 | kaputa
# Processing Record 23 of the Set 2 | luderitz
# Processing Record 24 of the Set 2 | avarua
# Processing Record 25 of the Set 2 | rikitea
# Processing Record 26 of the Set 2 | alta floresta
# Processing Record 27 of the Set 2 | new norfolk
# Processing Record 28 of the Set 2 | mataura
# Processing Record 29 of the Set 2 | puerto ayora
# Processing Record 30 of the Set 2 | hithadhoo
# Processing Record 31 of the Set 2 | atuona
# Processing Record 32 of the Set 2 | mahebourg
# Processing Record 33 of the Set 2 | bredasdorp
# Processing Record 34 of the Set 2 | victoria
# Processing Record 35 of the Set 2 | new norfolk
# Processing Record 36 of the Set 2 | jamestown
# Processing Record 37 of the Set 2 | lebu
# Processing Record 38 of the Set 2 | jaru
# Processing Record 39 of the Set 2 | luwuk
# Processing Record 40 of the Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 41 of the Set 2 | carnarvon
# Processing Record 42 of the Set 2 | vaini
# City not found. Skipping...
# Processing Record 43 of the Set 2 | ushuaia
# Processing Record 44 of the Set 2 | plettenberg bay
# Processing Record 45 of the Set 2 | asau
# Processing Record 46 of the Set 2 | castro
# Processing Record 47 of the Set 2 | vaini
# City not found. Skipping...
# Processing Record 48 of the Set 2 | senanga
# Processing Record 49 of the Set 2 | ancud
# Processing Record 50 of the Set 2 | metro
# Processing Record 1 of the Set 3 | punta arenas
# Processing Record 2 of the Set 3 | mataura
# Processing Record 3 of the Set 3 | albany
# Processing Record 4 of the Set 3 | rikitea
# Processing Record 5 of the Set 3 | bluff
# Processing Record 6 of the Set 3 | grand river south east
# Processing Record 7 of the Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 8 of the Set 3 | fare
# Processing Record 9 of the Set 3 | port alfred
# Processing Record 10 of the Set 3 | hermanus
# Processing Record 11 of the Set 3 | martapura
# Processing Record 12 of the Set 3 | lebu
# Processing Record 13 of the Set 3 | rikitea
# Processing Record 14 of the Set 3 | puerto ayora
# Processing Record 15 of the Set 3 | kruisfontein
# Processing Record 16 of the Set 3 | vaini
# City not found. Skipping...
# Processing Record 17 of the Set 3 | bredasdorp
# Processing Record 18 of the Set 3 | albany
# Processing Record 19 of the Set 3 | labuhan
# Processing Record 20 of the Set 3 | arraial do cabo
# Processing Record 21 of the Set 3 | isangel
# Processing Record 22 of the Set 3 | rikitea
# Processing Record 23 of the Set 3 | punta arenas
# Processing Record 24 of the Set 3 | rikitea
# Processing Record 25 of the Set 3 | albany
# Processing Record 26 of the Set 3 | santa rosa
# Processing Record 27 of the Set 3 | rikitea
# Processing Record 28 of the Set 3 | punta arenas
# Processing Record 29 of the Set 3 | lolua
# Processing Record 30 of the Set 3 | bluff
# Processing Record 31 of the Set 3 | port alfred
# Processing Record 32 of the Set 3 | villa carlos paz
# Processing Record 33 of the Set 3 | hobart
# Processing Record 34 of the Set 3 | coquimbo
# Processing Record 35 of the Set 3 | ushuaia
# Processing Record 36 of the Set 3 | fare
# Processing Record 37 of the Set 3 | faanui
# Processing Record 38 of the Set 3 | bengkulu
# Processing Record 39 of the Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 40 of the Set 3 | punta arenas
# Processing Record 41 of the Set 3 | hermanus
# Processing Record 42 of the Set 3 | vaini
# City not found. Skipping...
# Processing Record 43 of the Set 3 | maragogi
# Processing Record 44 of the Set 3 | bredasdorp
# Processing Record 45 of the Set 3 | ushuaia
# Processing Record 46 of the Set 3 | lebu
# Processing Record 47 of the Set 3 | port elizabeth
# Processing Record 48 of the Set 3 | punta arenas
# Processing Record 49 of the Set 3 | jilib
# Processing Record 50 of the Set 3 | luderitz
# Processing Record 1 of the Set 4 | rikitea
# Processing Record 2 of the Set 4 | gondanglegi
# Processing Record 3 of the Set 4 | atuona
# Processing Record 4 of the Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 5 of the Set 4 | molteno
# Processing Record 6 of the Set 4 | punta arenas
# Processing Record 7 of the Set 4 | mataura
# Processing Record 8 of the Set 4 | san cristobal
# Processing Record 9 of the Set 4 | singojuruh
# Processing Record 10 of the Set 4 | georgetown
# Processing Record 11 of the Set 4 | rikitea
# Processing Record 12 of the Set 4 | lebu
# Processing Record 13 of the Set 4 | georgetown
# Processing Record 14 of the Set 4 | albany
# Processing Record 15 of the Set 4 | puerto ayora
# Processing Record 16 of the Set 4 | port elizabeth
# Processing Record 17 of the Set 4 | cape town
# Processing Record 18 of the Set 4 | vaini
# City not found. Skipping...
# Processing Record 19 of the Set 4 | faanui
# Processing Record 20 of the Set 4 | ushuaia
# Processing Record 21 of the Set 4 | mahebourg
# Processing Record 22 of the Set 4 | broome
# Processing Record 23 of the Set 4 | vao
# Processing Record 24 of the Set 4 | rikitea
# Processing Record 25 of the Set 4 | bredasdorp
# Processing Record 26 of the Set 4 | hermanus
# Processing Record 27 of the Set 4 | hermanus
# Processing Record 28 of the Set 4 | victoria
# Processing Record 29 of the Set 4 | viedma
# Processing Record 30 of the Set 4 | faanui
# Processing Record 31 of the Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 32 of the Set 4 | jamestown
# Processing Record 33 of the Set 4 | rikitea
# Processing Record 34 of the Set 4 | miraflores
# Processing Record 35 of the Set 4 | kaoma
# Processing Record 36 of the Set 4 | caravelas
# Processing Record 37 of the Set 4 | port alfred
# Processing Record 38 of the Set 4 | jamestown
# Processing Record 39 of the Set 4 | busselton
# Processing Record 40 of the Set 4 | kirakira
# Processing Record 41 of the Set 4 | yulara
# Processing Record 42 of the Set 4 | rikitea
# Processing Record 43 of the Set 4 | busselton
# Processing Record 44 of the Set 4 | ushuaia
# Processing Record 45 of the Set 4 | arraial do cabo
# Processing Record 46 of the Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 47 of the Set 4 | new norfolk
# Processing Record 48 of the Set 4 | coihaique
# Processing Record 49 of the Set 4 | albany
# Processing Record 50 of the Set 4 | arraial do cabo
# Processing Record 1 of the Set 5 | bambous virieux
# Processing Record 2 of the Set 5 | mataura
# Processing Record 3 of the Set 5 | ushuaia
# Processing Record 4 of the Set 5 | jamestown
# Processing Record 5 of the Set 5 | diego de almagro
# Processing Record 6 of the Set 5 | avarua
# Processing Record 7 of the Set 5 | cuamba
# Processing Record 8 of the Set 5 | rikitea
# Processing Record 9 of the Set 5 | ushuaia
# Processing Record 10 of the Set 5 | port elizabeth
# Processing Record 11 of the Set 5 | punta arenas
# Processing Record 12 of the Set 5 | hermanus
# Processing Record 13 of the Set 5 | mataura
# Processing Record 14 of the Set 5 | hermanus
# Processing Record 15 of the Set 5 | avarua
# Processing Record 16 of the Set 5 | lakatoro
# Processing Record 17 of the Set 5 | hobart
# Processing Record 18 of the Set 5 | mataura
# Processing Record 19 of the Set 5 | plettenberg bay
# Processing Record 20 of the Set 5 | chuy
# Processing Record 21 of the Set 5 | hobart
# Processing Record 22 of the Set 5 | albany
# Processing Record 23 of the Set 5 | kiunga
# Processing Record 24 of the Set 5 | albany
# Processing Record 25 of the Set 5 | rikitea
# Processing Record 26 of the Set 5 | arraial do cabo
# Processing Record 27 of the Set 5 | lebu
# Processing Record 28 of the Set 5 | bluff
# Processing Record 29 of the Set 5 | puerto ayora
# Processing Record 30 of the Set 5 | atuona
# Processing Record 31 of the Set 5 | hermanus
# Processing Record 32 of the Set 5 | albany
# Processing Record 33 of the Set 5 | east london
# Processing Record 34 of the Set 5 | hobart
# Processing Record 35 of the Set 5 | grand river south east
# Processing Record 36 of the Set 5 | carnarvon
# Processing Record 37 of the Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 38 of the Set 5 | punta arenas
# Processing Record 39 of the Set 5 | atuona
# Processing Record 40 of the Set 5 | ushuaia
# Processing Record 41 of the Set 5 | mataura
# Processing Record 42 of the Set 5 | ushuaia
# Processing Record 43 of the Set 5 | poum
# Processing Record 44 of the Set 5 | rikitea
# Processing Record 45 of the Set 5 | east london
# Processing Record 46 of the Set 5 | ushuaia
# Processing Record 47 of the Set 5 | rikitea
# Processing Record 48 of the Set 5 | quatre cocos
# Processing Record 49 of the Set 5 | punta arenas
# Processing Record 50 of the Set 5 | rikitea
# Processing Record 1 of the Set 6 | kaitangata
# Processing Record 2 of the Set 6 | sehithwa
# Processing Record 3 of the Set 6 | bredasdorp
# Processing Record 4 of the Set 6 | mataura
# Processing Record 5 of the Set 6 | ushuaia
# Processing Record 6 of the Set 6 | belmonte
# Processing Record 7 of the Set 6 | richards bay
# Processing Record 8 of the Set 6 | rivadavia
# Processing Record 9 of the Set 6 | lebu
# Processing Record 10 of the Set 6 | jamestown
# Processing Record 11 of the Set 6 | ahipara
# Processing Record 12 of the Set 6 | east london
# Processing Record 13 of the Set 6 | fayaoue
# Processing Record 14 of the Set 6 | bengkulu
# Processing Record 15 of the Set 6 | albany
# Processing Record 16 of the Set 6 | padang
# Processing Record 17 of the Set 6 | atuona
# Processing Record 18 of the Set 6 | takoradi
# Processing Record 19 of the Set 6 | luderitz
# Processing Record 20 of the Set 6 | ushuaia
# Processing Record 21 of the Set 6 | port alfred
# Processing Record 22 of the Set 6 | cape town
# Processing Record 23 of the Set 6 | jamestown
# Processing Record 24 of the Set 6 | bluff
# Processing Record 25 of the Set 6 | mataura
# Processing Record 26 of the Set 6 | rikitea
# Processing Record 27 of the Set 6 | hambantota
# Processing Record 28 of the Set 6 | esperance
# Processing Record 29 of the Set 6 | ushuaia
# Processing Record 30 of the Set 6 | avarua
# Processing Record 31 of the Set 6 | rikitea
# Processing Record 32 of the Set 6 | chuy
# Processing Record 33 of the Set 6 | bluff
# Processing Record 34 of the Set 6 | souillac
# Processing Record 35 of the Set 6 | taolanaro
# City not found. Skipping...
# Processing Record 36 of the Set 6 | nabire
# Processing Record 37 of the Set 6 | albany
# Processing Record 38 of the Set 6 | hithadhoo
# Processing Record 39 of the Set 6 | cape town
# Processing Record 40 of the Set 6 | laguna
# Processing Record 41 of the Set 6 | avarua
# Processing Record 42 of the Set 6 | ouesso
# Processing Record 43 of the Set 6 | ushuaia
# Processing Record 44 of the Set 6 | busselton
# Processing Record 45 of the Set 6 | busselton
# Processing Record 46 of the Set 6 | punta arenas
# Processing Record 47 of the Set 6 | cape town
# Processing Record 48 of the Set 6 | georgetown
# Processing Record 49 of the Set 6 | kaitangata
# Processing Record 50 of the Set 6 | jamestown
# Processing Record 1 of the Set 7 | atuona
# Processing Record 2 of the Set 7 | avarua
# Processing Record 3 of the Set 7 | albany
# Processing Record 4 of the Set 7 | vaini
# City not found. Skipping...
# Processing Record 5 of the Set 7 | geraldton
# Processing Record 6 of the Set 7 | saint-philippe
# Processing Record 7 of the Set 7 | padang
# Processing Record 8 of the Set 7 | mahebourg
# Processing Record 9 of the Set 7 | saint-philippe
# Processing Record 10 of the Set 7 | ancud
# Processing Record 11 of the Set 7 | laguna
# Processing Record 12 of the Set 7 | ushuaia
# Processing Record 13 of the Set 7 | innisfail
# Processing Record 14 of the Set 7 | mataura
# Processing Record 15 of the Set 7 | bluff
# Processing Record 16 of the Set 7 | cidreira
# Processing Record 17 of the Set 7 | busselton
# Processing Record 18 of the Set 7 | punta arenas
# Processing Record 19 of the Set 7 | bengkulu
# Processing Record 20 of the Set 7 | walvis bay
# Processing Record 21 of the Set 7 | marcona
# City not found. Skipping...
# Processing Record 22 of the Set 7 | hobart
# Processing Record 23 of the Set 7 | vaini
# City not found. Skipping...
# Processing Record 24 of the Set 7 | waingapu
# Processing Record 25 of the Set 7 | huamachuco
# City not found. Skipping...
# Processing Record 26 of the Set 7 | ushuaia
# Processing Record 27 of the Set 7 | ushuaia
# Processing Record 28 of the Set 7 | bluff
# Processing Record 29 of the Set 7 | mataura
# Processing Record 30 of the Set 7 | jamestown
# Processing Record 31 of the Set 7 | port elizabeth
# Processing Record 32 of the Set 7 | puerto ayora
# Processing Record 33 of the Set 7 | hobart
# Processing Record 34 of the Set 7 | esperance
# Processing Record 35 of the Set 7 | rikitea
# Processing Record 36 of the Set 7 | new norfolk
# Processing Record 37 of the Set 7 | ushuaia
# Processing Record 38 of the Set 7 | bluff
# Processing Record 39 of the Set 7 | bambous virieux
# Processing Record 40 of the Set 7 | bluff
# Processing Record 41 of the Set 7 | ushuaia
# Processing Record 42 of the Set 7 | new norfolk
# Processing Record 43 of the Set 7 | te anau
# Processing Record 44 of the Set 7 | busselton
# Processing Record 45 of the Set 7 | mataura
# Processing Record 46 of the Set 7 | carnarvon
# Processing Record 47 of the Set 7 | mayumba
# Processing Record 48 of the Set 7 | hobart
# Processing Record 49 of the Set 7 | auki
# Processing Record 50 of the Set 7 | taolanaro
# City not found. Skipping...
# Processing Record 1 of the Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of the Set 8 | mendahara
# Processing Record 3 of the Set 8 | ushuaia
# Processing Record 4 of the Set 8 | georgetown
# Processing Record 5 of the Set 8 | mataura
# Processing Record 6 of the Set 8 | comodoro rivadavia
# Processing Record 7 of the Set 8 | boa viagem
# Processing Record 8 of the Set 8 | mataura
# Processing Record 9 of the Set 8 | rikitea
# Processing Record 10 of the Set 8 | ushuaia
# Processing Record 11 of the Set 8 | georgetown
# Processing Record 12 of the Set 8 | hithadhoo
# Processing Record 13 of the Set 8 | ushuaia
# Processing Record 14 of the Set 8 | port hedland
# Processing Record 15 of the Set 8 | mataura
# Processing Record 16 of the Set 8 | breves
# Processing Record 17 of the Set 8 | georgetown
# Processing Record 18 of the Set 8 | arraial do cabo
# Processing Record 19 of the Set 8 | rikitea
# Processing Record 20 of the Set 8 | cape town
# Processing Record 21 of the Set 8 | rikitea
# Processing Record 22 of the Set 8 | ushuaia
# Processing Record 23 of the Set 8 | punta arenas
# Processing Record 24 of the Set 8 | jamestown
# Processing Record 25 of the Set 8 | barra do bugres
# Processing Record 26 of the Set 8 | port alfred
# Processing Record 27 of the Set 8 | itarema
# Processing Record 28 of the Set 8 | hithadhoo
# Processing Record 29 of the Set 8 | kaeo
# Processing Record 30 of the Set 8 | rikitea
# Processing Record 31 of the Set 8 | rungata
# City not found. Skipping...
# Processing Record 32 of the Set 8 | hermanus
# Processing Record 33 of the Set 8 | mataura
# Processing Record 34 of the Set 8 | mataura
# Processing Record 35 of the Set 8 | kiunga
# Processing Record 36 of the Set 8 | ushuaia
# Processing Record 37 of the Set 8 | cape town
# Processing Record 38 of the Set 8 | punta arenas
# Processing Record 39 of the Set 8 | ushuaia
# Processing Record 40 of the Set 8 | avarua
# Processing Record 41 of the Set 8 | rio gallegos
# Processing Record 42 of the Set 8 | jamestown
# Processing Record 43 of the Set 8 | taolanaro
# City not found. Skipping...
# Processing Record 44 of the Set 8 | avarua
# Processing Record 45 of the Set 8 | albany
# Processing Record 46 of the Set 8 | ushuaia
# Processing Record 47 of the Set 8 | busselton
# Processing Record 48 of the Set 8 | mataura
# Processing Record 49 of the Set 8 | grand gaube
# Processing Record 50 of the Set 8 | saint-philippe
# Processing Record 1 of the Set 9 | jamestown
# Processing Record 2 of the Set 9 | jamestown
# Processing Record 3 of the Set 9 | busselton
# Processing Record 4 of the Set 9 | mataura
# Processing Record 5 of the Set 9 | busselton
# Processing Record 6 of the Set 9 | rikitea
# Processing Record 7 of the Set 9 | mar del plata
# Processing Record 8 of the Set 9 | bluff
# Processing Record 9 of the Set 9 | meulaboh
# Processing Record 10 of the Set 9 | rikitea
# Processing Record 11 of the Set 9 | hermanus
# Processing Record 12 of the Set 9 | rio gallegos
# Processing Record 13 of the Set 9 | inhambane
# Processing Record 14 of the Set 9 | saint-joseph
# Processing Record 15 of the Set 9 | hobart
# Processing Record 16 of the Set 9 | jamestown
# Processing Record 17 of the Set 9 | hermanus
# Processing Record 18 of the Set 9 | ushuaia
# Processing Record 19 of the Set 9 | le port
# Processing Record 20 of the Set 9 | hobart
# Processing Record 21 of the Set 9 | saint-philippe
# Processing Record 22 of the Set 9 | castro
# Processing Record 23 of the Set 9 | salinas
# Processing Record 24 of the Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 25 of the Set 9 | hambantota
# Processing Record 26 of the Set 9 | rikitea
# Processing Record 27 of the Set 9 | taolanaro
# City not found. Skipping...
# Processing Record 28 of the Set 9 | avarua
# Processing Record 29 of the Set 9 | rikitea
# Processing Record 30 of the Set 9 | port alfred
# Processing Record 31 of the Set 9 | vaini
# Processing Record 32 of the Set 9 | bluff
# Processing Record 33 of the Set 9 | mar del plata
# Processing Record 34 of the Set 9 | taolanaro
# City not found. Skipping...
# Processing Record 35 of the Set 9 | busselton
# Processing Record 36 of the Set 9 | ahipara
# Processing Record 37 of the Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 38 of the Set 9 | grand river south east
# Processing Record 39 of the Set 9 | nkhotakota
# Processing Record 40 of the Set 9 | rikitea
# Processing Record 41 of the Set 9 | olinda
# Processing Record 42 of the Set 9 | ushuaia
# Processing Record 43 of the Set 9 | new norfolk
# Processing Record 44 of the Set 9 | arraial do cabo
# Processing Record 45 of the Set 9 | rikitea
# Processing Record 46 of the Set 9 | taolanaro
# City not found. Skipping...
# Processing Record 47 of the Set 9 | castro
# Processing Record 48 of the Set 9 | bluff
# Processing Record 49 of the Set 9 | punta arenas
# Processing Record 50 of the Set 9 | ushuaia
# Processing Record 1 of the Set 10 | samusu
# City not found. Skipping...
# Processing Record 2 of the Set 10 | ushuaia
# Processing Record 3 of the Set 10 | georgetown
# Processing Record 4 of the Set 10 | garissa
# Processing Record 5 of the Set 10 | ushuaia
# Processing Record 6 of the Set 10 | atuona
# Processing Record 7 of the Set 10 | atuona
# Processing Record 8 of the Set 10 | ahipara
# Processing Record 9 of the Set 10 | ushuaia
# Processing Record 10 of the Set 10 | puerto ayora
# Processing Record 11 of the Set 10 | gizo
# Processing Record 12 of the Set 10 | coquimbo
# Processing Record 13 of the Set 10 | mataura
# Processing Record 14 of the Set 10 | luderitz
# Processing Record 15 of the Set 10 | hermanus
# Processing Record 16 of the Set 10 | mahebourg
# Processing Record 17 of the Set 10 | kirakira
# Processing Record 18 of the Set 10 | ushuaia
# Processing Record 19 of the Set 10 | hithadhoo
# Processing Record 20 of the Set 10 | jamestown
# Processing Record 21 of the Set 10 | biak
# Processing Record 22 of the Set 10 | busselton
# Processing Record 23 of the Set 10 | faanui
# Processing Record 24 of the Set 10 | vaini
# Processing Record 25 of the Set 10 | byron bay
# Processing Record 26 of the Set 10 | burnie
# Processing Record 27 of the Set 10 | ushuaia
# Processing Record 28 of the Set 10 | georgetown
# Processing Record 29 of the Set 10 | punta arenas
# Processing Record 30 of the Set 10 | umzimvubu
# Processing Record 31 of the Set 10 | new norfolk
# Processing Record 32 of the Set 10 | kaitangata
# Processing Record 33 of the Set 10 | mar del plata
# Processing Record 34 of the Set 10 | punta arenas
# Processing Record 35 of the Set 10 | mataura
# Processing Record 36 of the Set 10 | grand river south east
# Processing Record 37 of the Set 10 | taolanaro
# City not found. Skipping...
# Processing Record 38 of the Set 10 | busselton
# Processing Record 39 of the Set 10 | richards bay
# Processing Record 40 of the Set 10 | busselton
# Processing Record 41 of the Set 10 | taolanaro
# City not found. Skipping...
# Processing Record 42 of the Set 10 | mataura
# Processing Record 43 of the Set 10 | santa isabel do rio negro
# Processing Record 44 of the Set 10 | ushuaia
# Processing Record 45 of the Set 10 | auki
# Processing Record 46 of the Set 10 | lebu
# Processing Record 47 of the Set 10 | ushuaia
# Processing Record 48 of the Set 10 | cape town
# Processing Record 49 of the Set 10 | chuy
# Processing Record 50 of the Set 10 | lata
# Processing Record 1 of the Set 11 | saldanha
# Processing Record 2 of the Set 11 | hobart
# Processing Record 3 of the Set 11 | kruisfontein
# Processing Record 4 of the Set 11 | mataura
# Processing Record 5 of the Set 11 | caravelas
# Processing Record 6 of the Set 11 | castro
# Processing Record 7 of the Set 11 | olinda
# Processing Record 8 of the Set 11 | comodoro rivadavia
# Processing Record 9 of the Set 11 | port elizabeth
# Processing Record 10 of the Set 11 | mataura
# Processing Record 11 of the Set 11 | jamestown
# Processing Record 12 of the Set 11 | cidreira
# Processing Record 13 of the Set 11 | ushuaia
# Processing Record 14 of the Set 11 | joao pessoa
# Processing Record 15 of the Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 16 of the Set 11 | bulawayo
# Processing Record 17 of the Set 11 | grand river south east
# Processing Record 18 of the Set 11 | busselton
# Processing Record 19 of the Set 11 | georgetown
# Processing Record 20 of the Set 11 | necochea
# Processing Record 21 of the Set 11 | grand river south east
# Processing Record 22 of the Set 11 | avarua
# Processing Record 23 of the Set 11 | arraial do cabo
# Processing Record 24 of the Set 11 | east london
# Processing Record 25 of the Set 11 | hermanus
# Processing Record 26 of the Set 11 | chuy
# Processing Record 27 of the Set 11 | victoria
# Processing Record 28 of the Set 11 | taolanaro
# City not found. Skipping...
# Processing Record 29 of the Set 11 | rikitea
# Processing Record 30 of the Set 11 | guarapari
# Processing Record 31 of the Set 11 | albany
# Processing Record 32 of the Set 11 | rikitea
# Processing Record 33 of the Set 11 | punta arenas
# Processing Record 34 of the Set 11 | mataura
# Processing Record 35 of the Set 11 | cape town
# Processing Record 36 of the Set 11 | castro
# Processing Record 37 of the Set 11 | port alfred
# Processing Record 38 of the Set 11 | albany
# Processing Record 39 of the Set 11 | punta arenas
# Processing Record 40 of the Set 11 | puerto ayora
# Processing Record 41 of the Set 11 | port lincoln
# Processing Record 42 of the Set 11 | vaini
# Processing Record 43 of the Set 11 | grand gaube
# Processing Record 44 of the Set 11 | arraial do cabo
# Processing Record 45 of the Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 46 of the Set 11 | bluff
# Processing Record 47 of the Set 11 | east london
# Processing Record 48 of the Set 11 | georgetown
# Processing Record 49 of the Set 11 | challapata
# Processing Record 50 of the Set 11 | padang
# Processing Record 1 of the Set 12 | mataura
# Processing Record 2 of the Set 12 | mataura
# Processing Record 3 of the Set 12 | saint-philippe
# Processing Record 4 of the Set 12 | taolanaro
# City not found. Skipping...
# Processing Record 5 of the Set 12 | avarua
# Processing Record 6 of the Set 12 | narrabri
# Processing Record 7 of the Set 12 | cape town
# Processing Record 8 of the Set 12 | mataura
# Processing Record 9 of the Set 12 | vaini
# Processing Record 10 of the Set 12 | vaini
# Processing Record 11 of the Set 12 | ushuaia
# Processing Record 12 of the Set 12 | atuona
# Processing Record 13 of the Set 12 | taolanaro
# City not found. Skipping...
# Processing Record 14 of the Set 12 | ushuaia
# Processing Record 15 of the Set 12 | asau
# Processing Record 16 of the Set 12 | souillac
# Processing Record 17 of the Set 12 | hithadhoo
# Processing Record 18 of the Set 12 | mataura
# Processing Record 19 of the Set 12 | ushuaia
# Processing Record 20 of the Set 12 | arraial do cabo
# Processing Record 21 of the Set 12 | samusu
# City not found. Skipping...
# Processing Record 22 of the Set 12 | dunda
# Processing Record 23 of the Set 12 | mataura
# Processing Record 24 of the Set 12 | albany
# Processing Record 25 of the Set 12 | mataura
# Processing Record 26 of the Set 12 | hermanus
# Processing Record 27 of the Set 12 | micheweni
# Processing Record 28 of the Set 12 | castro
# Processing Record 29 of the Set 12 | rikitea
# Processing Record 30 of the Set 12 | mataura
# Processing Record 31 of the Set 12 | pisco
# City not found. Skipping...
# Processing Record 32 of the Set 12 | barcelos
# Processing Record 33 of the Set 12 | albany
# Processing Record 34 of the Set 12 | hermanus
# Processing Record 35 of the Set 12 | busselton
# Processing Record 36 of the Set 12 | poya
# Processing Record 37 of the Set 12 | port alfred
# Processing Record 38 of the Set 12 | conceicao do araguaia
# Processing Record 39 of the Set 12 | rikitea
# Processing Record 40 of the Set 12 | bengkulu
# Processing Record 41 of the Set 12 | east london
# Processing Record 42 of the Set 12 | bluff
# Processing Record 43 of the Set 12 | hermanus
# Processing Record 44 of the Set 12 | arraial do cabo
# Processing Record 45 of the Set 12 | katherine
# Processing Record 46 of the Set 12 | mataura
# Processing Record 47 of the Set 12 | busselton
# Processing Record 48 of the Set 12 | lufilufi
# City not found. Skipping...
# Processing Record 49 of the Set 12 | cape town
# Processing Record 50 of the Set 12 | hobart
# Processing Record 1 of the Set 13 | mataura
# Processing Record 2 of the Set 13 | albany
# Processing Record 3 of the Set 13 | ushuaia
# Processing Record 4 of the Set 13 | morondava
# City not found. Skipping...
# Processing Record 5 of the Set 13 | albany
# Processing Record 6 of the Set 13 | chilca
# City not found. Skipping...
# Processing Record 7 of the Set 13 | new norfolk
# Processing Record 8 of the Set 13 | san cristobal
# Processing Record 9 of the Set 13 | pisco
# City not found. Skipping...
# Processing Record 10 of the Set 13 | mount gambier
# Processing Record 11 of the Set 13 | bredasdorp
# Processing Record 12 of the Set 13 | port alfred
# Processing Record 13 of the Set 13 | rikitea
# Processing Record 14 of the Set 13 | castro
# Processing Record 15 of the Set 13 | punta arenas
# Processing Record 16 of the Set 13 | albany
# Processing Record 17 of the Set 13 | palabuhanratu
# Processing Record 18 of the Set 13 | vila velha
# Processing Record 19 of the Set 13 | tabou
# Processing Record 20 of the Set 13 | ushuaia
# Processing Record 21 of the Set 13 | vaini
# Processing Record 22 of the Set 13 | busselton
# Processing Record 23 of the Set 13 | asau
# Processing Record 24 of the Set 13 | kaeo
# Processing Record 25 of the Set 13 | punta arenas
# Processing Record 26 of the Set 13 | bambous virieux
# Processing Record 27 of the Set 13 | kieta
# Processing Record 28 of the Set 13 | palabuhanratu
# Processing Record 29 of the Set 13 | curuguaty
# Processing Record 30 of the Set 13 | tabou
# Processing Record 31 of the Set 13 | chuy
# Processing Record 32 of the Set 13 | atuona
# Processing Record 33 of the Set 13 | ushuaia
# Processing Record 34 of the Set 13 | hermanus
# Processing Record 35 of the Set 13 | ushuaia
# Processing Record 36 of the Set 13 | rawson
# Processing Record 37 of the Set 13 | port lincoln
# Processing Record 38 of the Set 13 | namatanai
# Processing Record 39 of the Set 13 | pergamino
# Processing Record 40 of the Set 13 | new norfolk
# Processing Record 41 of the Set 13 | cape town
# Processing Record 42 of the Set 13 | trelew
# Processing Record 43 of the Set 13 | albany
# Processing Record 44 of the Set 13 | vaini
# Processing Record 45 of the Set 13 | christchurch
# Processing Record 46 of the Set 13 | hithadhoo
# Processing Record 47 of the Set 13 | merauke
# Processing Record 48 of the Set 13 | saleaula
# City not found. Skipping...
# Processing Record 49 of the Set 13 | irpa irpa
# Processing Record 50 of the Set 13 | busselton
# Processing Record 1 of the Set 14 | carnarvon
# Processing Record 2 of the Set 14 | flinders
# Processing Record 3 of the Set 14 | faanui
# Processing Record 4 of the Set 14 | rawson
# Processing Record 5 of the Set 14 | mount isa
# Processing Record 6 of the Set 14 | port elizabeth
# Processing Record 7 of the Set 14 | samarai
# Processing Record 8 of the Set 14 | arraial do cabo
# Processing Record 9 of the Set 14 | sataua
# City not found. Skipping...
# Processing Record 10 of the Set 14 | cape town
# Processing Record 11 of the Set 14 | albany
# Processing Record 12 of the Set 14 | mwinilunga
# Processing Record 13 of the Set 14 | castro
# Processing Record 14 of the Set 14 | albany
# Processing Record 15 of the Set 14 | ushuaia
# Processing Record 16 of the Set 14 | kaitangata
# Processing Record 17 of the Set 14 | vaini
# Processing Record 18 of the Set 14 | luderitz
# Processing Record 19 of the Set 14 | isangel
# Processing Record 20 of the Set 14 | east london
# Processing Record 21 of the Set 14 | taolanaro
# City not found. Skipping...
# Processing Record 22 of the Set 14 | bluff
# Processing Record 23 of the Set 14 | marcona
# City not found. Skipping...
# Processing Record 24 of the Set 14 | castro
# Processing Record 25 of the Set 14 | victoria
# Processing Record 26 of the Set 14 | sechura
# City not found. Skipping...
# Processing Record 27 of the Set 14 | punta arenas
# Processing Record 28 of the Set 14 | mataura
# Processing Record 29 of the Set 14 | busselton
# Processing Record 30 of the Set 14 | vaini
# Processing Record 31 of the Set 14 | bengkulu
# Processing Record 32 of the Set 14 | ushuaia
# Processing Record 33 of the Set 14 | busselton
# Processing Record 34 of the Set 14 | sijunjung
# Processing Record 35 of the Set 14 | cape town
# Processing Record 36 of the Set 14 | georgetown
# Processing Record 37 of the Set 14 | poum
# Processing Record 38 of the Set 14 | hanmer springs
# Processing Record 39 of the Set 14 | umzimvubu
# Processing Record 40 of the Set 14 | jamestown
# Processing Record 41 of the Set 14 | rikitea
# Processing Record 42 of the Set 14 | punta arenas
# Processing Record 43 of the Set 14 | laguna
# Processing Record 44 of the Set 14 | kununurra
# Processing Record 45 of the Set 14 | hermanus
# Processing Record 46 of the Set 14 | hobart
# Processing Record 47 of the Set 14 | saint-philippe
# Processing Record 48 of the Set 14 | east london
# Processing Record 49 of the Set 14 | rikitea
# Processing Record 50 of the Set 14 | port alfred
# Processing Record 1 of the Set 15 | mataura
# Processing Record 2 of the Set 15 | ushuaia
# Processing Record 3 of the Set 15 | punta arenas
# Processing Record 4 of the Set 15 | belmonte
# Processing Record 5 of the Set 15 | bluff
# Processing Record 6 of the Set 15 | atuona
# Processing Record 7 of the Set 15 | samusu
# City not found. Skipping...
# Processing Record 8 of the Set 15 | ambilobe
# City not found. Skipping...
# Processing Record 9 of the Set 15 | hithadhoo
# Processing Record 10 of the Set 15 | ushuaia
# Processing Record 11 of the Set 15 | albany
# Processing Record 12 of the Set 15 | busselton
# Processing Record 13 of the Set 15 | victoria
# Processing Record 14 of the Set 15 | lata
# Processing Record 15 of the Set 15 | hithadhoo
# Processing Record 16 of the Set 15 | ushuaia
# Processing Record 17 of the Set 15 | bluff
# Processing Record 18 of the Set 15 | new norfolk
# Processing Record 19 of the Set 15 | punta arenas
# Processing Record 20 of the Set 15 | quatre cocos
# Processing Record 21 of the Set 15 | gamba
# Processing Record 22 of the Set 15 | hermanus
# Processing Record 23 of the Set 15 | lichinga
# Processing Record 24 of the Set 15 | lusambo
# Processing Record 25 of the Set 15 | vaini
# Processing Record 26 of the Set 15 | luderitz
# Processing Record 27 of the Set 15 | ushuaia
# Processing Record 28 of the Set 15 | grand gaube
# Processing Record 29 of the Set 15 | bluff
# Processing Record 30 of the Set 15 | rikitea
# Processing Record 31 of the Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 32 of the Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 33 of the Set 15 | busselton
# Processing Record 34 of the Set 15 | punta arenas
# Processing Record 35 of the Set 15 | broome
# Processing Record 36 of the Set 15 | mayor pablo lagerenza
# Processing Record 37 of the Set 15 | lebu
# Processing Record 38 of the Set 15 | sataua
# City not found. Skipping...
# Processing Record 39 of the Set 15 | kaitangata
# Processing Record 40 of the Set 15 | east london
# Processing Record 41 of the Set 15 | atuona
# Processing Record 42 of the Set 15 | avarua
# Processing Record 43 of the Set 15 | vaini
# Processing Record 44 of the Set 15 | neuquen
# Processing Record 45 of the Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 46 of the Set 15 | punta arenas
# Processing Record 47 of the Set 15 | busselton
# Processing Record 48 of the Set 15 | mataura
# Processing Record 49 of the Set 15 | vaini
# Processing Record 50 of the Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 1 of the Set 16 | alyangula
# Processing Record 2 of the Set 16 | bukama
# Processing Record 3 of the Set 16 | bambous virieux
# Processing Record 4 of the Set 16 | jamestown
# Processing Record 5 of the Set 16 | rikitea
# Processing Record 6 of the Set 16 | hermanus
# Processing Record 7 of the Set 16 | albany
# Processing Record 8 of the Set 16 | henties bay
# Processing Record 9 of the Set 16 | lebu
# Processing Record 10 of the Set 16 | lebu
# Processing Record 11 of the Set 16 | punta arenas
# Processing Record 12 of the Set 16 | puerto ayora
# Processing Record 13 of the Set 16 | hambantota
# Processing Record 14 of the Set 16 | ushuaia
# Processing Record 15 of the Set 16 | axim
# Processing Record 16 of the Set 16 | linhares
# Processing Record 17 of the Set 16 | hithadhoo
# Processing Record 18 of the Set 16 | mahebourg
# Processing Record 19 of the Set 16 | kaitangata
# Processing Record 20 of the Set 16 | saint-philippe
# Processing Record 21 of the Set 16 | east london
# Processing Record 22 of the Set 16 | vaini
# Processing Record 23 of the Set 16 | mar del plata
# Processing Record 24 of the Set 16 | rikitea
# Processing Record 25 of the Set 16 | busselton
# Processing Record 26 of the Set 16 | rio grande
# Processing Record 27 of the Set 16 | mildura
# Processing Record 28 of the Set 16 | flinders
# Processing Record 29 of the Set 16 | santiago
# Processing Record 30 of the Set 16 | cananeia
# Processing Record 31 of the Set 16 | cape town
# Processing Record 32 of the Set 16 | chinhoyi
# Processing Record 33 of the Set 16 | rikitea
# Processing Record 34 of the Set 16 | rikitea
# Processing Record 35 of the Set 16 | japura
# Processing Record 36 of the Set 16 | natal
# Processing Record 37 of the Set 16 | ushuaia
# Processing Record 38 of the Set 16 | bredasdorp
# Processing Record 39 of the Set 16 | kaeo
# Processing Record 40 of the Set 16 | rikitea
# Processing Record 41 of the Set 16 | rikitea
# Processing Record 42 of the Set 16 | cidreira
# Processing Record 43 of the Set 16 | lorengau
# Processing Record 44 of the Set 16 | hermanus
# Processing Record 45 of the Set 16 | ushuaia
# Processing Record 46 of the Set 16 | carnarvon
# Processing Record 47 of the Set 16 | cape town
# Processing Record 48 of the Set 16 | georgetown
# Processing Record 49 of the Set 16 | mahebourg
# Processing Record 50 of the Set 16 | hobart
# Processing Record 1 of the Set 17 | carnarvon
# Processing Record 2 of the Set 17 | hermanus
# Processing Record 3 of the Set 17 | conde
# Processing Record 4 of the Set 17 | rikitea
# Processing Record 5 of the Set 17 | rikitea
# Processing Record 6 of the Set 17 | vila velha
# Processing Record 7 of the Set 17 | mataura
# Processing Record 8 of the Set 17 | punta arenas
# Processing Record 9 of the Set 17 | port elizabeth
# Processing Record 10 of the Set 17 | albany
# Processing Record 11 of the Set 17 | rikitea
# Processing Record 12 of the Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 13 of the Set 17 | ushuaia
# Processing Record 14 of the Set 17 | castro
# Processing Record 15 of the Set 17 | samusu
# City not found. Skipping...
# Processing Record 16 of the Set 17 | new norfolk
# Processing Record 17 of the Set 17 | alyangula
# Processing Record 18 of the Set 17 | tuatapere
# Processing Record 19 of the Set 17 | albany
# Processing Record 20 of the Set 17 | new norfolk
# Processing Record 21 of the Set 17 | ahipara
# Processing Record 22 of the Set 17 | umzimvubu
# Processing Record 23 of the Set 17 | beloha
# City not found. Skipping...
# Processing Record 24 of the Set 17 | biak
# Processing Record 25 of the Set 17 | punta arenas
# Processing Record 26 of the Set 17 | puerto ayora
# Processing Record 27 of the Set 17 | kaitangata
# Processing Record 28 of the Set 17 | charters towers
# Processing Record 29 of the Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 30 of the Set 17 | busselton
# Processing Record 31 of the Set 17 | carnarvon
# Processing Record 32 of the Set 17 | rikitea
# Processing Record 33 of the Set 17 | hermanus
# Processing Record 34 of the Set 17 | ushuaia
# Processing Record 35 of the Set 17 | jamestown
# Processing Record 36 of the Set 17 | vaini
# Processing Record 37 of the Set 17 | constitucion
# Processing Record 38 of the Set 17 | boyolangu
# Processing Record 39 of the Set 17 | ushuaia
# Processing Record 40 of the Set 17 | bengkulu
# Processing Record 41 of the Set 17 | pouembout
# Processing Record 42 of the Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 43 of the Set 17 | punta arenas
# Processing Record 44 of the Set 17 | yulara
# Processing Record 45 of the Set 17 | hobart
# Processing Record 46 of the Set 17 | albany
# Processing Record 47 of the Set 17 | carnarvon
# Processing Record 48 of the Set 17 | kieta
# Processing Record 49 of the Set 17 | rikitea
# Processing Record 50 of the Set 17 | arraial do cabo
# Processing Record 1 of the Set 18 | atuona
# Processing Record 2 of the Set 18 | lata
# Processing Record 3 of the Set 18 | taolanaro
# City not found. Skipping...
# Processing Record 4 of the Set 18 | hambantota
# Processing Record 5 of the Set 18 | luwuk
# Processing Record 6 of the Set 18 | vaini
# Processing Record 7 of the Set 18 | rikitea
# Processing Record 8 of the Set 18 | atuona
# Processing Record 9 of the Set 18 | ushuaia
# Processing Record 10 of the Set 18 | bengkulu
# Processing Record 11 of the Set 18 | rikitea
# Processing Record 12 of the Set 18 | mataura
# Processing Record 13 of the Set 18 | albany
# Processing Record 14 of the Set 18 | punta arenas
# Processing Record 15 of the Set 18 | bluff
# Processing Record 16 of the Set 18 | kununurra
# Processing Record 17 of the Set 18 | mataura
# Processing Record 18 of the Set 18 | vaini
# Processing Record 19 of the Set 18 | vaini
# Processing Record 20 of the Set 18 | rikitea
# Processing Record 21 of the Set 18 | lebu
# Processing Record 22 of the Set 18 | mataura
# Processing Record 23 of the Set 18 | busselton
# Processing Record 24 of the Set 18 | samarai
# Processing Record 25 of the Set 18 | senanga
# Processing Record 26 of the Set 18 | jaciara
# Processing Record 27 of the Set 18 | rikitea
# Processing Record 28 of the Set 18 | ushuaia
# Processing Record 29 of the Set 18 | castro
# Processing Record 30 of the Set 18 | bluff
# Processing Record 31 of the Set 18 | pisco
# Processing Record 32 of the Set 18 | bluff
# Processing Record 33 of the Set 18 | busselton
# Processing Record 34 of the Set 18 | busselton
# Processing Record 35 of the Set 18 | puerto ayora
# Processing Record 36 of the Set 18 | papara
# Processing Record 37 of the Set 18 | punta arenas
# Processing Record 38 of the Set 18 | port augusta
# Processing Record 39 of the Set 18 | tingi
# Processing Record 40 of the Set 18 | bredasdorp
# Processing Record 41 of the Set 18 | vaitape
# Processing Record 42 of the Set 18 | manggar
# Processing Record 43 of the Set 18 | ushuaia
# Processing Record 44 of the Set 18 | ushuaia
# Processing Record 45 of the Set 18 | punta arenas
# Processing Record 46 of the Set 18 | victoria
# Processing Record 47 of the Set 18 | jaragua do sul
# Processing Record 48 of the Set 18 | punta arenas
# Processing Record 49 of the Set 18 | puerto leguizamo
# Processing Record 50 of the Set 18 | beloha
# City not found. Skipping...
# Processing Record 1 of the Set 19 | luderitz
# Processing Record 2 of the Set 19 | bambous virieux
# Processing Record 3 of the Set 19 | tuatapere
# Processing Record 4 of the Set 19 | goya
# Processing Record 5 of the Set 19 | maningrida
# Processing Record 6 of the Set 19 | hobart
# Processing Record 7 of the Set 19 | bluff
# Processing Record 8 of the Set 19 | taolanaro
# City not found. Skipping...
# Processing Record 9 of the Set 19 | taolanaro
# City not found. Skipping...
# Processing Record 10 of the Set 19 | mataura
# Processing Record 11 of the Set 19 | busselton
# Processing Record 12 of the Set 19 | arraial do cabo
# Processing Record 13 of the Set 19 | concordia
# Processing Record 14 of the Set 19 | hobart
# Processing Record 15 of the Set 19 | punta arenas
# Processing Record 16 of the Set 19 | namibe
# Processing Record 17 of the Set 19 | tsihombe
# City not found. Skipping...
# Processing Record 18 of the Set 19 | rikitea
# Processing Record 19 of the Set 19 | vaini
# Processing Record 20 of the Set 19 | castro
# Processing Record 21 of the Set 19 | bengkulu
# Processing Record 22 of the Set 19 | bowen
# Processing Record 23 of the Set 19 | kununurra
# Processing Record 24 of the Set 19 | rikitea
# Processing Record 25 of the Set 19 | atuona
# Processing Record 26 of the Set 19 | souillac
# Processing Record 27 of the Set 19 | puerto ayora
# Processing Record 28 of the Set 19 | tiarei
# Processing Record 29 of the Set 19 | bluff
# Processing Record 30 of the Set 19 | new norfolk
# Processing Record 31 of the Set 19 | albany
# Processing Record 32 of the Set 19 | busselton
# Processing Record 33 of the Set 19 | faanui
# Processing Record 34 of the Set 19 | castro
# Processing Record 35 of the Set 19 | albany
# Processing Record 36 of the Set 19 | sorong
# Processing Record 37 of the Set 19 | namatanai
# Processing Record 38 of the Set 19 | hermanus
# Processing Record 39 of the Set 19 | namibe
# Processing Record 40 of the Set 19 | rikitea
# Processing Record 41 of the Set 19 | new norfolk
# Processing Record 42 of the Set 19 | carnarvon
# Processing Record 43 of the Set 19 | ahipara
# Processing Record 44 of the Set 19 | cape town
# Processing Record 45 of the Set 19 | broome
# Processing Record 46 of the Set 19 | poum
# Processing Record 47 of the Set 19 | georgetown
# Processing Record 48 of the Set 19 | vaini
# Processing Record 49 of the Set 19 | ushuaia
# Processing Record 50 of the Set 19 | taolanaro
# City not found. Skipping...
# Processing Record 1 of the Set 20 | mar del plata
# Processing Record 2 of the Set 20 | vaini
# Processing Record 3 of the Set 20 | east london
# Processing Record 4 of the Set 20 | albany
# Processing Record 5 of the Set 20 | ushuaia
# Processing Record 6 of the Set 20 | puerto ayora
# Processing Record 7 of the Set 20 | hobart
# Processing Record 8 of the Set 20 | vao
# Processing Record 9 of the Set 20 | bluff
# Processing Record 10 of the Set 20 | hermanus
# Processing Record 11 of the Set 20 | vaini
# Processing Record 12 of the Set 20 | rikitea
# Processing Record 13 of the Set 20 | busselton
# Processing Record 14 of the Set 20 | carnarvon
# Processing Record 15 of the Set 20 | albany
# Processing Record 16 of the Set 20 | beloha
# City not found. Skipping...
# Processing Record 17 of the Set 20 | rikitea
# Processing Record 18 of the Set 20 | rikitea
# Processing Record 19 of the Set 20 | port alfred
# Processing Record 20 of the Set 20 | albany
# Processing Record 21 of the Set 20 | grand river south east
# Processing Record 22 of the Set 20 | collie
# Processing Record 23 of the Set 20 | bluff
# Processing Record 24 of the Set 20 | bima
# Processing Record 25 of the Set 20 | hithadhoo
# Processing Record 26 of the Set 20 | coquimbo
# Processing Record 27 of the Set 20 | mar del plata
# Processing Record 28 of the Set 20 | esperance
# Processing Record 29 of the Set 20 | punta arenas
# Processing Record 30 of the Set 20 | mar del plata
# Processing Record 31 of the Set 20 | mar del plata
# Processing Record 32 of the Set 20 | saint-philippe
# Processing Record 33 of the Set 20 | viligili
# Processing Record 34 of the Set 20 | bluff
# Processing Record 35 of the Set 20 | kruisfontein
# Processing Record 36 of the Set 20 | namibe
# Processing Record 37 of the Set 20 | quatre cocos
# Processing Record 38 of the Set 20 | eirunepe
# Processing Record 39 of the Set 20 | rikitea
# Processing Record 40 of the Set 20 | bredasdorp
# Processing Record 41 of the Set 20 | huarmey
# Processing Record 42 of the Set 20 | gizo
# Processing Record 43 of the Set 20 | rikitea
# Processing Record 44 of the Set 20 | rikitea
# Processing Record 45 of the Set 20 | rikitea
# Processing Record 46 of the Set 20 | avarua
# Processing Record 47 of the Set 20 | rikitea
# Processing Record 48 of the Set 20 | punta arenas
# Processing Record 49 of the Set 20 | punta arenas
# Processing Record 50 of the Set 20 | emerald
# Processing Record 1 of the Set 21 | meulaboh
# Processing Record 2 of the Set 21 | rikitea
# Processing Record 3 of the Set 21 | punta arenas
# Processing Record 4 of the Set 21 | porto belo
# Processing Record 5 of the Set 21 | ushuaia
# Processing Record 6 of the Set 21 | alyangula
# ...
# Processing Record 18 of the Set 34 | koumac
# Processing Record 19 of the Set 34 | mataura
# Processing Record 20 of the Set 34 | kaeo
# Processing Record 21 of the Set 34 | grand river south east
# Processing Record 22 of the Set 34 | bluff
# Processing Record 23 of the Set 34 | lima
# Processing Record 24 of the Set 34 | mataura
# Processing Record 25 of the Set 34 | ushuaia
# Processing Record 26 of the Set 34 | taolanaro
# City not found. Skipping...
# Processing Record 27 of the Set 34 | cidreira
# Processing Record 28 of the Set 34 | puerto ayora
# Processing Record 29 of the Set 34 | mataura
# Processing Record 30 of the Set 34 | punta arenas
# Processing Record 31 of the Set 34 | fare
# Processing Record 32 of the Set 34 | vaini
# Processing Record 33 of the Set 34 | punta arenas
# Processing Record 34 of the Set 34 | puerto ayora
# Processing Record 35 of the Set 34 | njombe
# Processing Record 36 of the Set 34 | hermanus
# Processing Record 37 of the Set 34 | ushuaia
# Processing Record 38 of the Set 34 | necochea
# Processing Record 39 of the Set 34 | padang
# Processing Record 40 of the Set 34 | san cristobal
# Processing Record 41 of the Set 34 | hobart
# Processing Record 42 of the Set 34 | carmelo
# Processing Record 43 of the Set 34 | castro
# Processing Record 44 of the Set 34 | albany
# Processing Record 45 of the Set 34 | presidencia roque saenz pena
# Processing Record 46 of the Set 34 | rawson
# Processing Record 47 of the Set 34 | faanui
# Processing Record 48 of the Set 34 | georgetown
# Processing Record 49 of the Set 34 | mar del plata
# Processing Record 50 of the Set 34 | caravelas
# Processing Record 1 of the Set 35 | new norfolk
# Processing Record 2 of the Set 35 | salinas
# Processing Record 3 of the Set 35 | albany
# Processing Record 4 of the Set 35 | san cristobal
# Processing Record 5 of the Set 35 | mar del plata
# Processing Record 6 of the Set 35 | mataura
# Processing Record 7 of the Set 35 | mar del plata
# Processing Record 8 of the Set 35 | rikitea
# Processing Record 9 of the Set 35 | lebu
# Processing Record 10 of the Set 35 | carnarvon
# Processing Record 11 of the Set 35 | hithadhoo
# Processing Record 12 of the Set 35 | mahebourg
# Processing Record 13 of the Set 35 | punta arenas
# Processing Record 14 of the Set 35 | busselton
# Processing Record 15 of the Set 35 | esperance
# Processing Record 16 of the Set 35 | sao joao da barra
# Processing Record 17 of the Set 35 | lebu
# Processing Record 18 of the Set 35 | hobart
# Processing Record 19 of the Set 35 | albany
# Processing Record 20 of the Set 35 | hobart
# Processing Record 21 of the Set 35 | saint-philippe
# Processing Record 22 of the Set 35 | mataura
# Processing Record 23 of the Set 35 | asau
# Processing Record 24 of the Set 35 | namibe
# Processing Record 25 of the Set 35 | busselton
# Processing Record 26 of the Set 35 | coihaique
# Processing Record 27 of the Set 35 | rikitea
# Processing Record 28 of the Set 35 | ushuaia
# Processing Record 29 of the Set 35 | taolanaro
# City not found. Skipping...
# Processing Record 30 of the Set 35 | hermanus
# Processing Record 31 of the Set 35 | atuona
# Processing Record 32 of the Set 35 | sao felix do xingu
# Processing Record 33 of the Set 35 | taolanaro
# City not found. Skipping...
# Processing Record 34 of the Set 35 | hermanus
# Processing Record 35 of the Set 35 | lebu
# Processing Record 36 of the Set 35 | punta arenas
# Processing Record 37 of the Set 35 | avera
# Processing Record 38 of the Set 35 | puerto ayora
# Processing Record 39 of the Set 35 | rikitea
# Processing Record 40 of the Set 35 | kawalu
# Processing Record 41 of the Set 35 | hermanus
# Processing Record 42 of the Set 35 | rikitea
# Processing Record 43 of the Set 35 | rikitea
# Processing Record 44 of the Set 35 | faanui
# Processing Record 45 of the Set 35 | bluff
# Processing Record 46 of the Set 35 | gladstone
# Processing Record 47 of the Set 35 | kendari
# Processing Record 48 of the Set 35 | hobart
# Processing Record 49 of the Set 35 | alofi
# Processing Record 50 of the Set 35 | rikitea
# Processing Record 1 of the Set 36 | punta arenas
# Processing Record 2 of the Set 36 | taolanaro
# City not found. Skipping...
# Processing Record 3 of the Set 36 | busselton
# Processing Record 4 of the Set 36 | lolua
# Processing Record 5 of the Set 36 | saldanha
# Processing Record 6 of the Set 36 | bredasdorp
# Processing Record 7 of the Set 36 | punta arenas
# Processing Record 8 of the Set 36 | bengkulu
# Processing Record 9 of the Set 36 | puerto ayora
# Processing Record 10 of the Set 36 | vaini
# Processing Record 11 of the Set 36 | mar del plata
# Processing Record 12 of the Set 36 | mataura
# Processing Record 13 of the Set 36 | albany
# Processing Record 14 of the Set 36 | albany
# Processing Record 15 of the Set 36 | vila velha
# Processing Record 16 of the Set 36 | atuona
# Processing Record 17 of the Set 36 | hobart
# Processing Record 18 of the Set 36 | mondlo
# Processing Record 19 of the Set 36 | rikitea
# Processing Record 20 of the Set 36 | bluff
# Processing Record 21 of the Set 36 | taolanaro
# City not found. Skipping...
# Processing Record 22 of the Set 36 | mahebourg
# Processing Record 23 of the Set 36 | tuatapere
# Processing Record 24 of the Set 36 | mataura
# Processing Record 25 of the Set 36 | punta arenas
# Processing Record 26 of the Set 36 | carnarvon
# Processing Record 27 of the Set 36 | senador jose porfirio
# Processing Record 28 of the Set 36 | hobart
# Processing Record 29 of the Set 36 | ushuaia
# Processing Record 30 of the Set 36 | arraial do cabo
# Processing Record 31 of the Set 36 | jamestown
# Processing Record 32 of the Set 36 | mar del plata
# Processing Record 33 of the Set 36 | saint-philippe
# Processing Record 34 of the Set 36 | souillac
# Processing Record 35 of the Set 36 | rikitea
# Processing Record 36 of the Set 36 | port macquarie
# Processing Record 37 of the Set 36 | busselton
# Processing Record 38 of the Set 36 | jamestown
# Processing Record 39 of the Set 36 | ushuaia
# Processing Record 40 of the Set 36 | port alfred
# Processing Record 41 of the Set 36 | punta arenas
# Processing Record 42 of the Set 36 | albany
# Processing Record 43 of the Set 36 | chuy
# Processing Record 44 of the Set 36 | esperance
# Processing Record 45 of the Set 36 | bluff
# Processing Record 46 of the Set 36 | albany
# Processing Record 47 of the Set 36 | cidreira
# Processing Record 48 of the Set 36 | maceio
# Processing Record 49 of the Set 36 | saurimo
# Processing Record 50 of the Set 36 | taolanaro
# City not found. Skipping...
# Processing Record 1 of the Set 37 | san patricio
# Processing Record 2 of the Set 37 | laguna
# Processing Record 3 of the Set 37 | punta arenas
# Processing Record 4 of the Set 37 | ushuaia
# Processing Record 5 of the Set 37 | mataura
# Processing Record 6 of the Set 37 | dondo
# Processing Record 7 of the Set 37 | mataura
# Processing Record 8 of the Set 37 | taolanaro
# City not found. Skipping...
# Processing Record 9 of the Set 37 | lakes entrance
# Processing Record 10 of the Set 37 | yangambi
# Processing Record 11 of the Set 37 | albany
# Processing Record 12 of the Set 37 | kapit
# Processing Record 13 of the Set 37 | maracai
# Processing Record 14 of the Set 37 | rikitea
# Processing Record 15 of the Set 37 | albany
# Processing Record 16 of the Set 37 | vaini
# Processing Record 17 of the Set 37 | bredasdorp
# Processing Record 18 of the Set 37 | vaini
# Processing Record 19 of the Set 37 | busselton
# Processing Record 20 of the Set 37 | luderitz
# Processing Record 21 of the Set 37 | yulara
# Processing Record 22 of the Set 37 | rikitea
# Processing Record 23 of the Set 37 | port alfred
# Processing Record 24 of the Set 37 | port alfred
# Processing Record 25 of the Set 37 | miracema do tocantins
# Processing Record 26 of the Set 37 | jamestown
# Processing Record 27 of the Set 37 | albany
# Processing Record 28 of the Set 37 | chimbote
# Processing Record 29 of the Set 37 | hermanus
# Processing Record 30 of the Set 37 | mataura
# Processing Record 31 of the Set 37 | mount isa
# Processing Record 32 of the Set 37 | vaini
# Processing Record 33 of the Set 37 | taolanaro
# City not found. Skipping...
# Processing Record 34 of the Set 37 | alyangula
# Processing Record 35 of the Set 37 | ushuaia
# Processing Record 36 of the Set 37 | vaini
# Processing Record 37 of the Set 37 | tautira
# Processing Record 38 of the Set 37 | broome
# Processing Record 39 of the Set 37 | hermanus
# Processing Record 40 of the Set 37 | rikitea
# Processing Record 41 of the Set 37 | georgetown
# Processing Record 42 of the Set 37 | hobart
# Processing Record 43 of the Set 37 | bambous virieux
# Processing Record 44 of the Set 37 | matara
# Processing Record 45 of the Set 37 | mataura
# Processing Record 46 of the Set 37 | hithadhoo
# Processing Record 47 of the Set 37 | soyo
# Processing Record 48 of the Set 37 | puerto ayora
# Processing Record 49 of the Set 37 | westport
# Processing Record 50 of the Set 37 | hermanus
# Processing Record 1 of the Set 38 | ushuaia
# Processing Record 2 of the Set 38 | albany
# Processing Record 3 of the Set 38 | swan hill
# Processing Record 4 of the Set 38 | bengkulu
# Processing Record 5 of the Set 38 | santa teresa
# Processing Record 6 of the Set 38 | rikitea
# Processing Record 7 of the Set 38 | georgetown
# Processing Record 8 of the Set 38 | rikitea
# Processing Record 9 of the Set 38 | hermanus
# Processing Record 10 of the Set 38 | puerto ayora
# Processing Record 11 of the Set 38 | bluff
# Processing Record 12 of the Set 38 | bredasdorp
# Processing Record 13 of the Set 38 | mazagao
# Processing Record 14 of the Set 38 | rikitea
# Processing Record 15 of the Set 38 | conceicao da barra
# Processing Record 16 of the Set 38 | saint-philippe
# Processing Record 17 of the Set 38 | busselton
# Processing Record 18 of the Set 38 | port alfred
# Processing Record 19 of the Set 38 | saleaula
# City not found. Skipping...
# Processing Record 20 of the Set 38 | cape town
# Processing Record 21 of the Set 38 | arraial do cabo
# Processing Record 22 of the Set 38 | vaini
# Processing Record 23 of the Set 38 | namibe
# Processing Record 24 of the Set 38 | san cristobal
# Processing Record 25 of the Set 38 | ushuaia
# Processing Record 26 of the Set 38 | saint-philippe
# Processing Record 27 of the Set 38 | busselton
# Processing Record 28 of the Set 38 | port alfred
# Processing Record 29 of the Set 38 | buin
# Processing Record 30 of the Set 38 | bluff
# Processing Record 31 of the Set 38 | rikitea
# Processing Record 32 of the Set 38 | mataura
# Processing Record 33 of the Set 38 | talcahuano
# Processing Record 34 of the Set 38 | christchurch
# Processing Record 35 of the Set 38 | port augusta
# Processing Record 36 of the Set 38 | porto walter
# Processing Record 37 of the Set 38 | rikitea
# Processing Record 38 of the Set 38 | lata
# Processing Record 39 of the Set 38 | albany
# Processing Record 40 of the Set 38 | mataura
# Processing Record 41 of the Set 38 | port elizabeth
# Processing Record 42 of the Set 38 | punta arenas
# Processing Record 43 of the Set 38 | rikitea
# Processing Record 44 of the Set 38 | avarua
# Processing Record 45 of the Set 38 | saint-philippe
# Processing Record 46 of the Set 38 | rikitea
# Processing Record 47 of the Set 38 | vila velha
# Processing Record 48 of the Set 38 | tsihombe
# City not found. Skipping...
# Processing Record 49 of the Set 38 | carnarvon
# Processing Record 50 of the Set 38 | palembang
# Processing Record 1 of the Set 39 | albany
# Processing Record 2 of the Set 39 | mar del plata
# Processing Record 3 of the Set 39 | busselton
# Processing Record 4 of the Set 39 | ushuaia
# Processing Record 5 of the Set 39 | punta arenas
# Processing Record 6 of the Set 39 | tual
# Processing Record 7 of the Set 39 | samarai
# Processing Record 8 of the Set 39 | cape town
# Processing Record 9 of the Set 39 | port elizabeth
# Processing Record 10 of the Set 39 | jamestown
# Processing Record 11 of the Set 39 | georgetown
# Processing Record 12 of the Set 39 | albany
# Processing Record 13 of the Set 39 | port alfred
# Processing Record 14 of the Set 39 | puerto ayora
# Processing Record 15 of the Set 39 | hithadhoo
# Processing Record 16 of the Set 39 | cidreira
# Processing Record 17 of the Set 39 | georgetown
# Processing Record 18 of the Set 39 | rikitea
# Processing Record 19 of the Set 39 | hithadhoo
# Processing Record 20 of the Set 39 | rikitea
# Processing Record 21 of the Set 39 | mataura
# Processing Record 22 of the Set 39 | taperoa
# Processing Record 23 of the Set 39 | jamestown
# Processing Record 24 of the Set 39 | port alfred
# Processing Record 25 of the Set 39 | atuona
# Processing Record 26 of the Set 39 | ambilobe
# City not found. Skipping...
# Processing Record 27 of the Set 39 | saldanha
# Processing Record 28 of the Set 39 | faanui
# Processing Record 29 of the Set 39 | ushuaia
# Processing Record 30 of the Set 39 | saint-philippe
# Processing Record 31 of the Set 39 | umzimvubu
# Processing Record 32 of the Set 39 | isangel
# Processing Record 33 of the Set 39 | tautira
# Processing Record 34 of the Set 39 | bluff
# Processing Record 35 of the Set 39 | cape town
# Processing Record 36 of the Set 39 | salinas
# Processing Record 37 of the Set 39 | tocopilla
# Processing Record 38 of the Set 39 | hermanus
# Processing Record 39 of the Set 39 | necochea
# Processing Record 40 of the Set 39 | umzimvubu
# Processing Record 41 of the Set 39 | atuona
# Processing Record 42 of the Set 39 | punta arenas
# Processing Record 43 of the Set 39 | punta arenas
# Processing Record 44 of the Set 39 | vaini
# Processing Record 45 of the Set 39 | cape town
# Processing Record 46 of the Set 39 | hermanus
# Processing Record 47 of the Set 39 | taolanaro
# City not found. Skipping...
# Processing Record 48 of the Set 39 | rikitea
# Processing Record 49 of the Set 39 | sao geraldo do araguaia
# Processing Record 50 of the Set 39 | jamestown
# Processing Record 1 of the Set 40 | chuy
# Processing Record 2 of the Set 40 | geraldton
# Processing Record 3 of the Set 40 | rikitea
# Processing Record 4 of the Set 40 | jamestown
# Processing Record 5 of the Set 40 | bredasdorp
# Processing Record 6 of the Set 40 | ushuaia
# Processing Record 7 of the Set 40 | rikitea
# Processing Record 8 of the Set 40 | atuona
# Processing Record 9 of the Set 40 | taolanaro
# City not found. Skipping...
# Processing Record 10 of the Set 40 | punta arenas
# Processing Record 11 of the Set 40 | arraial do cabo
# Processing Record 12 of the Set 40 | port macquarie
# Processing Record 13 of the Set 40 | bredasdorp
# Processing Record 14 of the Set 40 | mataura
# Processing Record 15 of the Set 40 | comodoro rivadavia
# Processing Record 16 of the Set 40 | saint-philippe
# Processing Record 17 of the Set 40 | new norfolk
# Processing Record 18 of the Set 40 | punta arenas
# Processing Record 19 of the Set 40 | rikitea
# Processing Record 20 of the Set 40 | busselton
# Processing Record 21 of the Set 40 | ushuaia
# Processing Record 22 of the Set 40 | mount gambier
# Processing Record 23 of the Set 40 | rikitea
# Processing Record 24 of the Set 40 | grootfontein
# Processing Record 25 of the Set 40 | saint-philippe
# Processing Record 26 of the Set 40 | taolanaro
# City not found. Skipping...
# Processing Record 27 of the Set 40 | punta arenas
# Processing Record 28 of the Set 40 | copiapo
# Processing Record 29 of the Set 40 | rikitea
# Processing Record 30 of the Set 40 | punta arenas
# Processing Record 31 of the Set 40 | opuwo
# Processing Record 32 of the Set 40 | sechura
# Processing Record 33 of the Set 40 | busselton
# Processing Record 34 of the Set 40 | vaini
# Processing Record 35 of the Set 40 | punta arenas
# Processing Record 36 of the Set 40 | esperance
# Processing Record 37 of the Set 40 | punta arenas
# Processing Record 38 of the Set 40 | vaini
# Processing Record 39 of the Set 40 | busselton
# Processing Record 40 of the Set 40 | vaitape
# Processing Record 41 of the Set 40 | namwala
# Processing Record 42 of the Set 40 | rikitea
# Processing Record 43 of the Set 40 | busselton
# Processing Record 44 of the Set 40 | vaini
# Processing Record 45 of the Set 40 | taolanaro
# City not found. Skipping...
# Processing Record 46 of the Set 40 | faanui
# Processing Record 47 of the Set 40 | new norfolk
# Processing Record 48 of the Set 40 | maua
# Processing Record 49 of the Set 40 | alotau
# Processing Record 50 of the Set 40 | avarua
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Saldanha -33.0117   17.9442     57.02        78          88
# 1          Ushuaia -54.8000  -68.3000     40.66        75          75
# 2         Souillac -20.5167   57.5167     72.36        78          18
# 3            Bluff -46.6000  168.3333     51.80        58          91
# 4  Arraial Do Cabo -22.9661  -42.0278     69.89        93          14
# 5           Hobart -42.8794  147.3294     53.26        78          75
# 6          Rikitea -23.1203 -134.9692     73.42        69         100
# 7          Mataura -23.1203 -134.9692     73.42        69         100
# 8      San Antonio  29.4241  -98.4936     87.10        59           2
# 9          Sibolga   1.7427   98.7792     74.88        95         100
#
#    Wind Speed Country Current Description
# 0       14.58      ZA     overcast clouds
# 1       21.85      AR       broken clouds
# 2       15.08      MU          few clouds
# 3       22.39      NZ     overcast clouds
# 4       10.94      BR          few clouds
# 5        8.05      AU       broken clouds
# 6       17.25      PF     overcast clouds
# 7       17.25      PF     overcast clouds
# 8        8.39      US           clear sky
# 9        2.77      ID       moderate rain

# %%
# Create CSV file
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
